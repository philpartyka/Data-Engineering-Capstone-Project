# %% [markdown]
# ------------
# # Loading Data into MySQL

# %%
import pandas as pd
import mysql.connector as msql
from mysql.connector import Error
# This file contains our login information for the MySQL server
import credentials as C

# %% [markdown]
# Let's connect to the MySQL server and create a database called "creditcard_capstone".  If there is a connection error or if the table already exists then I will see an exception thrown.

# %%
try:
    conn=msql.connect(host = C.host_name, user = C.user_name, password = C.password)
    if conn.is_connected():
        cursor=conn.cursor()
        cursor.execute("CREATE DATABASE creditcard_capstone")
        print('Database is created')
except Error as e:
    print('Error while connecting to MySQL',e)
# Out:
# Error while connecting to MySQL 1007 (HY000): Can't create database 'creditcard_capstone'; database exists

# %% [markdown]
# Let's load the data that we will be loading onto the db.  We are using pandas instead of pyspark because of the structure of the json files.  When I created the json files I used a pandas function to save them.  Pandas saves the json in a columnar format but spark requires the json to be structured in a row based format.  I would have to add ```, orient='records', lines=True``` options to the pandas .to_json() write function in order to have json files that can be used by spark.  Since we won't be doing any more transformations on the data then I don't see a need to use pyspark anymore.

# %%
branch_df = pd.read_json("clean_data/branch.json")
cust_df = pd.read_json("clean_data/customer.json")
cc_df = pd.read_json("clean_data/credit_card.json")

# %% [markdown]
# Now lets establish the schema for the tables we will want to create

# %%
branch_table = (
"CREATE TABLE IF NOT EXISTS `cdw_sapp_branch` ("
"  `BRANCH_CODE` INT(3) NOT NULL,"
"  `BRANCH_NAME` VARCHAR(50) NULL,"
"  `BRANCH_STREET` VARCHAR(50) NULL,"
"  `BRANCH_CITY` VARCHAR(40) NULL,"
"  `BRANCH_STATE` VARCHAR(2) NULL,"
"  `BRANCH_ZIP` INT(5) ZEROFILL NULL,"  #had to use ZEROFILL because the leading 0s were being dropped
"  `BRANCH_PHONE` VARCHAR(13) NULL,"
"  `LAST_UPDATED` TIMESTAMP NULL,"
"  PRIMARY KEY (`BRANCH_CODE`))"
"ENGINE = InnoDB  ")

# %%
# I can't place the below comment because if I break up the string the query won't execute

cc_table = (
"CREATE TABLE IF NOT EXISTS `cdw_sapp_credit_card` ("
"  `TRANSACTION_ID` INT(5) NOT NULL,"
"  `CUST_CC_NO` VARCHAR(16) NULL,"
"  `TIMEID` VARCHAR(8) NULL,"
"  `CUST_SSN` INT(9) NULL,"
"  `BRANCH_CODE` INT(3) NULL,"
"  `TRANSACTION_TYPE` VARCHAR(40) NULL,"
"  `TRANSACTION_VALUE` DOUBLE(7,2) NULL," #had to limit the digits after the decimal because trans #46687 ended up being 5.56000000005
"  PRIMARY KEY (`TRANSACTION_ID`))"
"ENGINE = InnoDB  ")

# %%
cust_table = (
"CREATE TABLE IF NOT EXISTS `cdw_sapp_customer` ("
"  `SSN` INT(9) NOT NULL,"
"  `FIRST_NAME` VARCHAR(25) NULL,"
"  `MIDDLE_NAME` VARCHAR(25) NULL,"
"  `LAST_NAME` VARCHAR(25) NULL,"
"  `Credit_card_no` VARCHAR(16) NULL,"
"  `FULL_STREET_ADDRESS` VARCHAR(80) NULL,"
"  `CUST_CITY` VARCHAR(40) NULL,"
"  `CUST_STATE` VARCHAR(2) NULL,"
"  `CUST_COUNTRY` VARCHAR(50) NULL,"
"  `CUST_ZIP` INT(5) UNSIGNED ZEROFILL NULL,"  #had to use ZEROFILL because the leading 0s were being dropped
"  `CUST_PHONE` VARCHAR(15) NULL,"
"  `CUST_EMAIL` VARCHAR(60) NULL,"
"  `LAST_UPDATED` TIMESTAMP NULL,"
"  PRIMARY KEY (`SSN`))"
"ENGINE = InnoDB  ")

# %% [markdown]
# Let's load the branch data into the database.

# %%
try:
    conn = msql.connect(host = C.host_name, database = 'creditcard_capstone',
                        user = C.user_name, password = C.password)
    if conn.is_connected():
        cursor = conn.cursor()
        cursor.execute("select database();")
        record = cursor.fetchone()
        print("You're connected to database: ", record)

        #lets add the branch data into the db
        cursor.execute('DROP TABLE IF EXISTS cdw_sapp_branch;')
        print('Creating cdw_sapp_branch table....')
        cursor.execute(branch_table)
        print("cdw_sapp_branch table is created....")
        #loop through the data frame
        for i,row in branch_df.iterrows():
            #here %S represents each object in the row, one object per column
            sql = "INSERT INTO creditcard_capstone.cdw_sapp_branch\
                  VALUES (%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print(f"{i+1} Branch Records inserted")
            # the connection is not auto committed by default so we must commit to save our changes
            conn.commit()
        print("Branch data fulled loaded")

        #lets add the credit card transaction data to the db
        cursor.execute('DROP TABLE IF EXISTS cdw_sapp_credit_card;')
        print('Creating cdw_sapp_credit_card table....')
        cursor.execute(cc_table)
        print("cdw_sapp_credit_card table is created....")
        #loop through the data frame
        for i,row in cc_df.iterrows():
            sql = "INSERT INTO creditcard_capstone.cdw_sapp_credit_card\
                  VALUES (%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print(f"{i+1} CC Transaction Records inserted")
            conn.commit()
        print("Credit Card transaction data fulled loaded")

        #lets add the customer data to the db
        cursor.execute('DROP TABLE IF EXISTS cdw_sapp_customer;')
        print('Creating cdw_sapp_customer table....')
        cursor.execute(cust_table)
        print("cdw_sapp_customer table is created....")
        #loop through the data frame
        for i,row in cust_df.iterrows(): 
            sql = "INSERT INTO creditcard_capstone.cdw_sapp_customer\
                  VALUES (%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)"
            cursor.execute(sql, tuple(row))
            print(f"{i+1} Customer Records inserted")
            conn.commit()
        print("Customer data fulled loaded")
except Error as e:
            print("Error while connecting to MySQL", e)
# Out:
# You're connected to database:  ('creditcard_capstone',)
# Creating cdw_sapp_branch table....
# cdw_sapp_branch table is created....
# 1 Branch Records inserted
# 2 Branch Records inserted
# 3 Branch Records inserted
# 4 Branch Records inserted
# 5 Branch Records inserted
# 6 Branch Records inserted
# 7 Branch Records inserted
# 8 Branch Records inserted
# 9 Branch Records inserted
# 10 Branch Records inserted
# 11 Branch Records inserted
# 12 Branch Records inserted
# 13 Branch Records inserted
# 14 Branch Records inserted
# 15 Branch Records inserted
# 16 Branch Records inserted
# 17 Branch Records inserted
# 18 Branch Records inserted
# 19 Branch Records inserted
# 20 Branch Records inserted
# 21 Branch Records inserted
# 22 Branch Records inserted
# 23 Branch Records inserted
# 24 Branch Records inserted
# 25 Branch Records inserted
# 26 Branch Records inserted
# 27 Branch Records inserted
# 28 Branch Records inserted
# 29 Branch Records inserted
# 30 Branch Records inserted
# 31 Branch Records inserted
# 32 Branch Records inserted
# 33 Branch Records inserted
# 34 Branch Records inserted
# 35 Branch Records inserted
# 36 Branch Records inserted
# 37 Branch Records inserted
# 38 Branch Records inserted
# 39 Branch Records inserted
# 40 Branch Records inserted
# 41 Branch Records inserted
# 42 Branch Records inserted
# 43 Branch Records inserted
# 44 Branch Records inserted
# 45 Branch Records inserted
# 46 Branch Records inserted
# 47 Branch Records inserted
# 48 Branch Records inserted
# 49 Branch Records inserted
# 50 Branch Records inserted
# 51 Branch Records inserted
# 52 Branch Records inserted
# 53 Branch Records inserted
# 54 Branch Records inserted
# 55 Branch Records inserted
# 56 Branch Records inserted
# 57 Branch Records inserted
# 58 Branch Records inserted
# 59 Branch Records inserted
# 60 Branch Records inserted
# 61 Branch Records inserted
# 62 Branch Records inserted
# 63 Branch Records inserted
# 64 Branch Records inserted
# 65 Branch Records inserted
# 66 Branch Records inserted
# 67 Branch Records inserted
# 68 Branch Records inserted
# 69 Branch Records inserted
# 70 Branch Records inserted
# 71 Branch Records inserted
# 72 Branch Records inserted
# 73 Branch Records inserted
# 74 Branch Records inserted
# 75 Branch Records inserted
# 76 Branch Records inserted
# 77 Branch Records inserted
# 78 Branch Records inserted
# 79 Branch Records inserted
# 80 Branch Records inserted
# 81 Branch Records inserted
# 82 Branch Records inserted
# 83 Branch Records inserted
# 84 Branch Records inserted
# 85 Branch Records inserted
# 86 Branch Records inserted
# 87 Branch Records inserted
# 88 Branch Records inserted
# 89 Branch Records inserted
# 90 Branch Records inserted
# 91 Branch Records inserted
# 92 Branch Records inserted
# 93 Branch Records inserted
# 94 Branch Records inserted
# 95 Branch Records inserted
# 96 Branch Records inserted
# 97 Branch Records inserted
# 98 Branch Records inserted
# 99 Branch Records inserted
# 100 Branch Records inserted
# 101 Branch Records inserted
# 102 Branch Records inserted
# 103 Branch Records inserted
# 104 Branch Records inserted
# 105 Branch Records inserted
# 106 Branch Records inserted
# 107 Branch Records inserted
# 108 Branch Records inserted
# 109 Branch Records inserted
# 110 Branch Records inserted
# 111 Branch Records inserted
# 112 Branch Records inserted
# 113 Branch Records inserted
# 114 Branch Records inserted
# 115 Branch Records inserted
# Branch data fulled loaded
# Creating cdw_sapp_credit_card table....
# cdw_sapp_credit_card table is created....
# 1 CC Transaction Records inserted
# 2 CC Transaction Records inserted
# 3 CC Transaction Records inserted
# 4 CC Transaction Records inserted
# 5 CC Transaction Records inserted
# 6 CC Transaction Records inserted
# 7 CC Transaction Records inserted
# 8 CC Transaction Records inserted
# 9 CC Transaction Records inserted
# 10 CC Transaction Records inserted
# 11 CC Transaction Records inserted
# 12 CC Transaction Records inserted
# 13 CC Transaction Records inserted
# 14 CC Transaction Records inserted
# 15 CC Transaction Records inserted
# 16 CC Transaction Records inserted
# 17 CC Transaction Records inserted
# 18 CC Transaction Records inserted
# 19 CC Transaction Records inserted
# 20 CC Transaction Records inserted
# 21 CC Transaction Records inserted
# 22 CC Transaction Records inserted
# 23 CC Transaction Records inserted
# 1185 CC Transaction Records inserted
# 1186 CC Transaction Records inserted
# 1187 CC Transaction Records inserted
# 1188 CC Transaction Records inserted
# 1189 CC Transaction Records inserted
# 1190 CC Transaction Records inserted
# 1191 CC Transaction Records inserted
# 1192 CC Transaction Records inserted
# 1193 CC Transaction Records inserted
# 1194 CC Transaction Records inserted
# 1195 CC Transaction Records inserted
# 1196 CC Transaction Records inserted
# 1197 CC Transaction Records inserted
# 1198 CC Transaction Records inserted
# 1199 CC Transaction Records inserted
# 1200 CC Transaction Records inserted
# 1201 CC Transaction Records inserted
# 1202 CC Transaction Records inserted
# 1203 CC Transaction Records inserted
# 1204 CC Transaction Records inserted
# 1205 CC Transaction Records inserted
# 1206 CC Transaction Records inserted
# 1207 CC Transaction Records inserted
# 1208 CC Transaction Records inserted
# 1209 CC Transaction Records inserted
# 1210 CC Transaction Records inserted
# 1211 CC Transaction Records inserted
# 1212 CC Transaction Records inserted
# 1213 CC Transaction Records inserted
# 1214 CC Transaction Records inserted
# 1215 CC Transaction Records inserted
# 1216 CC Transaction Records inserted
# 1217 CC Transaction Records inserted
# 1218 CC Transaction Records inserted
# 1219 CC Transaction Records inserted
# 1220 CC Transaction Records inserted
# 1221 CC Transaction Records inserted
# 1222 CC Transaction Records inserted
# 1223 CC Transaction Records inserted
# 1224 CC Transaction Records inserted
# 1225 CC Transaction Records inserted
# 1226 CC Transaction Records inserted
# 1227 CC Transaction Records inserted
# 1228 CC Transaction Records inserted
# 1229 CC Transaction Records inserted
# 1230 CC Transaction Records inserted
# 1231 CC Transaction Records inserted
# 1232 CC Transaction Records inserted
# 1233 CC Transaction Records inserted
# 1234 CC Transaction Records inserted
# 1235 CC Transaction Records inserted
# 1236 CC Transaction Records inserted
# ...
# 421 Customer Records inserted
# 422 Customer Records inserted
# 423 Customer Records inserted
# 424 Customer Records inserted
# 425 Customer Records inserted
# 426 Customer Records inserted
# 427 Customer Records inserted
# 428 Customer Records inserted
# 429 Customer Records inserted
# 430 Customer Records inserted
# 431 Customer Records inserted
# 432 Customer Records inserted
# 433 Customer Records inserted
# 434 Customer Records inserted
# 435 Customer Records inserted
# 436 Customer Records inserted
# 437 Customer Records inserted
# 438 Customer Records inserted
# 439 Customer Records inserted
# 440 Customer Records inserted
# 441 Customer Records inserted
# 442 Customer Records inserted
# 443 Customer Records inserted
# 444 Customer Records inserted
# 445 Customer Records inserted
# 446 Customer Records inserted
# 447 Customer Records inserted
# 448 Customer Records inserted
# 449 Customer Records inserted
# 450 Customer Records inserted
# 451 Customer Records inserted
# 452 Customer Records inserted
# 453 Customer Records inserted
# 454 Customer Records inserted
# 455 Customer Records inserted
# 456 Customer Records inserted
# 457 Customer Records inserted
# 458 Customer Records inserted
# 459 Customer Records inserted
# 460 Customer Records inserted
# 461 Customer Records inserted
# 462 Customer Records inserted
# 463 Customer Records inserted
# 464 Customer Records inserted
# 465 Customer Records inserted
# 466 Customer Records inserted
# 467 Customer Records inserted
# 468 Customer Records inserted
# 469 Customer Records inserted
# 470 Customer Records inserted
# 471 Customer Records inserted
# 472 Customer Records inserted
# 473 Customer Records inserted
# 474 Customer Records inserted
# 475 Customer Records inserted
# 476 Customer Records inserted
# 477 Customer Records inserted
# 478 Customer Records inserted
# 479 Customer Records inserted
# 480 Customer Records inserted
# 481 Customer Records inserted
# 482 Customer Records inserted
# 483 Customer Records inserted
# 484 Customer Records inserted
# 485 Customer Records inserted
# 486 Customer Records inserted
# 487 Customer Records inserted
# 488 Customer Records inserted
# 489 Customer Records inserted
# 490 Customer Records inserted
# 491 Customer Records inserted
# 492 Customer Records inserted
# 493 Customer Records inserted
# 494 Customer Records inserted
# 495 Customer Records inserted
# 496 Customer Records inserted
# 497 Customer Records inserted
# 498 Customer Records inserted
# 499 Customer Records inserted
# 500 Customer Records inserted
# 501 Customer Records inserted
# 502 Customer Records inserted
# 503 Customer Records inserted
# 504 Customer Records inserted
# 505 Customer Records inserted
# 506 Customer Records inserted
# 507 Customer Records inserted
# 508 Customer Records inserted
# 509 Customer Records inserted
# 510 Customer Records inserted
# 511 Customer Records inserted
# 512 Customer Records inserted
# 513 Customer Records inserted
# 514 Customer Records inserted
# 515 Customer Records inserted
# 516 Customer Records inserted
# 517 Customer Records inserted
# 518 Customer Records inserted
# 519 Customer Records inserted
# 520 Customer Records inserted
# 521 Customer Records inserted
# 522 Customer Records inserted
# 523 Customer Records inserted
# 524 Customer Records inserted
# 525 Customer Records inserted
# 526 Customer Records inserted
# 527 Customer Records inserted
# 528 Customer Records inserted
# 529 Customer Records inserted
# 530 Customer Records inserted
# 531 Customer Records inserted
# 532 Customer Records inserted
# 533 Customer Records inserted
# 534 Customer Records inserted
# 535 Customer Records inserted
# 536 Customer Records inserted
# 537 Customer Records inserted
# 538 Customer Records inserted
# 539 Customer Records inserted
# 540 Customer Records inserted
# 541 Customer Records inserted
# 542 Customer Records inserted
# 543 Customer Records inserted
# 544 Customer Records inserted
# 545 Customer Records inserted
# 546 Customer Records inserted
# 547 Customer Records inserted
# 548 Customer Records inserted
# 549 Customer Records inserted
# 550 Customer Records inserted
# 551 Customer Records inserted
# 552 Customer Records inserted
# 553 Customer Records inserted
# 554 Customer Records inserted
# 555 Customer Records inserted
# 556 Customer Records inserted
# 557 Customer Records inserted
# 558 Customer Records inserted
# 559 Customer Records inserted
# 560 Customer Records inserted
# 561 Customer Records inserted
# 562 Customer Records inserted
# 563 Customer Records inserted
# 564 Customer Records inserted
# 565 Customer Records inserted
# 566 Customer Records inserted
# 567 Customer Records inserted
# 568 Customer Records inserted
# 569 Customer Records inserted
# 570 Customer Records inserted
# 571 Customer Records inserted
# 572 Customer Records inserted
# 573 Customer Records inserted
# 574 Customer Records inserted
# 575 Customer Records inserted
# 576 Customer Records inserted
# 577 Customer Records inserted
# 578 Customer Records inserted
# 579 Customer Records inserted
# 580 Customer Records inserted
# 581 Customer Records inserted
# 582 Customer Records inserted
# 583 Customer Records inserted
# 584 Customer Records inserted
# 585 Customer Records inserted
# 586 Customer Records inserted
# 587 Customer Records inserted
# 588 Customer Records inserted
# 589 Customer Records inserted
# 590 Customer Records inserted
# 591 Customer Records inserted
# 592 Customer Records inserted
# 593 Customer Records inserted
# 594 Customer Records inserted
# 595 Customer Records inserted
# 596 Customer Records inserted
# 597 Customer Records inserted
# 598 Customer Records inserted
# 599 Customer Records inserted
# 600 Customer Records inserted
# 601 Customer Records inserted
# 602 Customer Records inserted
# 603 Customer Records inserted
# 604 Customer Records inserted
# 605 Customer Records inserted
# 606 Customer Records inserted
# 607 Customer Records inserted
# 608 Customer Records inserted
# 609 Customer Records inserted
# 610 Customer Records inserted
# 611 Customer Records inserted
# 612 Customer Records inserted
# 613 Customer Records inserted
# 614 Customer Records inserted
# 615 Customer Records inserted
# 616 Customer Records inserted
# 617 Customer Records inserted
# 618 Customer Records inserted
# 619 Customer Records inserted
# 620 Customer Records inserted
# 621 Customer Records inserted
# 622 Customer Records inserted
# 623 Customer Records inserted
# 624 Customer Records inserted
# 625 Customer Records inserted
# 626 Customer Records inserted
# 627 Customer Records inserted
# 628 Customer Records inserted
# 629 Customer Records inserted
# 630 Customer Records inserted
# 631 Customer Records inserted
# 632 Customer Records inserted
# 633 Customer Records inserted
# 634 Customer Records inserted
# 635 Customer Records inserted
# 636 Customer Records inserted
# 637 Customer Records inserted
# 638 Customer Records inserted
# 639 Customer Records inserted
# 640 Customer Records inserted
# 641 Customer Records inserted
# 642 Customer Records inserted
# 643 Customer Records inserted
# 644 Customer Records inserted
# 645 Customer Records inserted
# 646 Customer Records inserted
# 647 Customer Records inserted
# 648 Customer Records inserted
# 649 Customer Records inserted
# 650 Customer Records inserted
# 651 Customer Records inserted
# 652 Customer Records inserted
# 653 Customer Records inserted
# 654 Customer Records inserted
# 655 Customer Records inserted
# 656 Customer Records inserted
# 657 Customer Records inserted
# 658 Customer Records inserted
# 659 Customer Records inserted
# 660 Customer Records inserted
# 661 Customer Records inserted
# 662 Customer Records inserted
# 663 Customer Records inserted
# 664 Customer Records inserted
# 665 Customer Records inserted
# 666 Customer Records inserted
# 667 Customer Records inserted
# 668 Customer Records inserted
# 669 Customer Records inserted
# 670 Customer Records inserted
# 671 Customer Records inserted
# 672 Customer Records inserted
# 673 Customer Records inserted
# 674 Customer Records inserted
# 675 Customer Records inserted
# 676 Customer Records inserted
# 677 Customer Records inserted
# 678 Customer Records inserted
# 679 Customer Records inserted
# 680 Customer Records inserted
# 681 Customer Records inserted
# 682 Customer Records inserted
# 683 Customer Records inserted
# 684 Customer Records inserted
# 685 Customer Records inserted
# 686 Customer Records inserted
# 687 Customer Records inserted
# 688 Customer Records inserted
# 689 Customer Records inserted
# 690 Customer Records inserted
# 691 Customer Records inserted
# 692 Customer Records inserted
# 693 Customer Records inserted
# 694 Customer Records inserted
# 695 Customer Records inserted
# 696 Customer Records inserted
# 697 Customer Records inserted
# 698 Customer Records inserted
# 699 Customer Records inserted
# 700 Customer Records inserted
# 701 Customer Records inserted
# 702 Customer Records inserted
# 703 Customer Records inserted
# 704 Customer Records inserted
# 705 Customer Records inserted
# 706 Customer Records inserted
# 707 Customer Records inserted
# 708 Customer Records inserted
# 709 Customer Records inserted
# 710 Customer Records inserted
# 711 Customer Records inserted
# 712 Customer Records inserted
# 713 Customer Records inserted
# 714 Customer Records inserted
# 715 Customer Records inserted
# 716 Customer Records inserted
# 717 Customer Records inserted
# 718 Customer Records inserted
# 719 Customer Records inserted
# 720 Customer Records inserted
# 721 Customer Records inserted
# 722 Customer Records inserted
# 723 Customer Records inserted
# 724 Customer Records inserted
# 725 Customer Records inserted
# 726 Customer Records inserted
# 727 Customer Records inserted
# 728 Customer Records inserted
# 729 Customer Records inserted
# 730 Customer Records inserted
# 731 Customer Records inserted
# 732 Customer Records inserted
# 733 Customer Records inserted
# 734 Customer Records inserted
# 735 Customer Records inserted
# 736 Customer Records inserted
# 737 Customer Records inserted
# 738 Customer Records inserted
# 739 Customer Records inserted
# 740 Customer Records inserted
# 741 Customer Records inserted
# 742 Customer Records inserted
# 743 Customer Records inserted
# 744 Customer Records inserted
# 745 Customer Records inserted
# 746 Customer Records inserted
# 747 Customer Records inserted
# 748 Customer Records inserted
# 749 Customer Records inserted
# 750 Customer Records inserted
# 751 Customer Records inserted
# 752 Customer Records inserted
# 753 Customer Records inserted
# 754 Customer Records inserted
# 755 Customer Records inserted
# 756 Customer Records inserted
# 757 Customer Records inserted
# 758 Customer Records inserted
# 759 Customer Records inserted
# 760 Customer Records inserted
# 761 Customer Records inserted
# 762 Customer Records inserted
# 763 Customer Records inserted
# 764 Customer Records inserted
# 765 Customer Records inserted
# 766 Customer Records inserted
# 767 Customer Records inserted
# 768 Customer Records inserted
# 769 Customer Records inserted
# 770 Customer Records inserted
# 771 Customer Records inserted
# 772 Customer Records inserted
# 773 Customer Records inserted
# 774 Customer Records inserted
# 775 Customer Records inserted
# 776 Customer Records inserted
# 777 Customer Records inserted
# 778 Customer Records inserted
# 779 Customer Records inserted
# 780 Customer Records inserted
# 781 Customer Records inserted
# 782 Customer Records inserted
# 783 Customer Records inserted
# 784 Customer Records inserted
# 785 Customer Records inserted
# 786 Customer Records inserted
# 787 Customer Records inserted
# 788 Customer Records inserted
# 789 Customer Records inserted
# 790 Customer Records inserted
# 791 Customer Records inserted
# 792 Customer Records inserted
# 793 Customer Records inserted
# 794 Customer Records inserted
# 795 Customer Records inserted
# 796 Customer Records inserted
# 797 Customer Records inserted
# 798 Customer Records inserted
# 799 Customer Records inserted
# 800 Customer Records inserted
# 801 Customer Records inserted
# 802 Customer Records inserted
# 803 Customer Records inserted
# 804 Customer Records inserted
# 805 Customer Records inserted
# 806 Customer Records inserted
# 807 Customer Records inserted
# 808 Customer Records inserted
# 809 Customer Records inserted
# 810 Customer Records inserted
# 811 Customer Records inserted
# 812 Customer Records inserted
# 813 Customer Records inserted
# 814 Customer Records inserted
# 815 Customer Records inserted
# 816 Customer Records inserted
# 817 Customer Records inserted
# 818 Customer Records inserted
# 819 Customer Records inserted
# 820 Customer Records inserted
# 821 Customer Records inserted
# 822 Customer Records inserted
# 823 Customer Records inserted
# 824 Customer Records inserted
# 825 Customer Records inserted
# 826 Customer Records inserted
# 827 Customer Records inserted
# 828 Customer Records inserted
# 829 Customer Records inserted
# 830 Customer Records inserted
# 831 Customer Records inserted
# 832 Customer Records inserted
# 833 Customer Records inserted
# 834 Customer Records inserted
# 835 Customer Records inserted
# 836 Customer Records inserted
# 837 Customer Records inserted
# 838 Customer Records inserted
# 839 Customer Records inserted
# 840 Customer Records inserted
# 841 Customer Records inserted
# 842 Customer Records inserted
# 843 Customer Records inserted
# 844 Customer Records inserted
# 845 Customer Records inserted
# 846 Customer Records inserted
# 847 Customer Records inserted
# 848 Customer Records inserted
# 849 Customer Records inserted
# 850 Customer Records inserted
# 851 Customer Records inserted
# 852 Customer Records inserted
# 853 Customer Records inserted
# 854 Customer Records inserted
# 855 Customer Records inserted
# 856 Customer Records inserted
# 857 Customer Records inserted
# 858 Customer Records inserted
# 859 Customer Records inserted
# 860 Customer Records inserted
# 861 Customer Records inserted
# 862 Customer Records inserted
# 863 Customer Records inserted
# 864 Customer Records inserted
# 865 Customer Records inserted
# 866 Customer Records inserted
# 867 Customer Records inserted
# 868 Customer Records inserted
# 869 Customer Records inserted
# 870 Customer Records inserted
# 871 Customer Records inserted
# 872 Customer Records inserted
# 873 Customer Records inserted
# 874 Customer Records inserted
# 875 Customer Records inserted
# 876 Customer Records inserted
# 877 Customer Records inserted
# 878 Customer Records inserted
# 879 Customer Records inserted
# 880 Customer Records inserted
# 881 Customer Records inserted
# 882 Customer Records inserted
# 883 Customer Records inserted
# 884 Customer Records inserted
# 885 Customer Records inserted
# 886 Customer Records inserted
# 887 Customer Records inserted
# 888 Customer Records inserted
# 889 Customer Records inserted
# 890 Customer Records inserted
# 891 Customer Records inserted
# 892 Customer Records inserted
# 893 Customer Records inserted
# 894 Customer Records inserted
# 895 Customer Records inserted
# 896 Customer Records inserted
# 897 Customer Records inserted
# 898 Customer Records inserted
# 899 Customer Records inserted
# 900 Customer Records inserted
# 901 Customer Records inserted
# 902 Customer Records inserted
# 903 Customer Records inserted
# 904 Customer Records inserted
# 905 Customer Records inserted
# 906 Customer Records inserted
# 907 Customer Records inserted
# 908 Customer Records inserted
# 909 Customer Records inserted
# 910 Customer Records inserted
# 911 Customer Records inserted
# 912 Customer Records inserted
# 913 Customer Records inserted
# 914 Customer Records inserted
# 915 Customer Records inserted
# 916 Customer Records inserted
# 917 Customer Records inserted
# 918 Customer Records inserted
# 919 Customer Records inserted
# 920 Customer Records inserted
# 921 Customer Records inserted
# 922 Customer Records inserted
# 923 Customer Records inserted
# 924 Customer Records inserted
# 925 Customer Records inserted
# 926 Customer Records inserted
# 927 Customer Records inserted
# 928 Customer Records inserted
# 929 Customer Records inserted
# 930 Customer Records inserted
# 931 Customer Records inserted
# 932 Customer Records inserted
# 933 Customer Records inserted
# 934 Customer Records inserted
# 935 Customer Records inserted
# 936 Customer Records inserted
# 937 Customer Records inserted
# 938 Customer Records inserted
# 939 Customer Records inserted
# 940 Customer Records inserted
# 941 Customer Records inserted
# 942 Customer Records inserted
# 943 Customer Records inserted
# 944 Customer Records inserted
# 945 Customer Records inserted
# 946 Customer Records inserted
# 947 Customer Records inserted
# 948 Customer Records inserted
# 949 Customer Records inserted
# 950 Customer Records inserted
# 951 Customer Records inserted
# 952 Customer Records inserted
# Customer data fulled loaded
